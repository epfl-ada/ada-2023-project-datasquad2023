# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from scipy import stats

# %matplotlib inline

# %% [markdown]
# ## Loads data and preprocess fields

# %%
df_vd_tech = pd.read_csv("./tech_review_videos.tsv.gz", compression="infer", sep="\t")
df_vd_tech["upload_date"] = pd.to_datetime(df_vd_tech["upload_date"])

# %%
df_vd_tech
# Out:
#                       channel_id  dislike_count   display_id  duration  \
# 0       UCzWQYUVCpZqtN93H8RR44Qw           87.0  ExOXF1x3N1g       292
# 1       UCzWQYUVCpZqtN93H8RR44Qw           36.0  _RhHuW2gglw       193
# 2       UCzWQYUVCpZqtN93H8RR44Qw           34.0  g513EUHqkfw       191
# 3       UCzVy1DW9NFp4c910hMd_jIw            1.0  fRY3dpFBF14       217
# 4       UCzVy1DW9NFp4c910hMd_jIw            3.0  VenwYvLRa-I       437
# ...                          ...            ...          ...       ...
# 178250  UCrwT2LIOntbglCR2o0iOXVw           20.0  WjcXvzzRB0M       196
# 178251  UCrwPkTBuhZJDgiHkWzY7COw           35.0  UySYfgQaIlo       200
# 178252  UCrwPkTBuhZJDgiHkWzY7COw            0.0  lqpuuKkh-lA       226
# 178253  UCrwMvZOgSvS2srsIjY-iIGg            0.0  7uFD7TYwlW4       182
# 178254  UCrwMvZOgSvS2srsIjY-iIGg            0.0  OuwVfKw_7Y4        30
#
#         like_count                                               tags  \
# 0           7386.0  current events,Science,biofuel,algae,power,Bio...
# 1           1933.0  Energy (Dimension),testtube,fertilizer,human w...
# 2           2556.0  social,networking,first impressions,judge,meet...
# 3             72.0  Sony,8K,Sony 8K,TV,2019 Sony 8K,8K Television,...
# 4            107.0  Bowers and Wilkins,B&W,Bowers,Wilkins,603,606,...
# ...            ...                                                ...
# 178250       486.0  surface book,best laptop for engineering,elect...
# 178251        31.0  how to install windows 10 on android phone,win...
# 178252        11.0  Best Video player for Android,video player,vid...
# 178253         7.0                                                NaN
# 178254         2.0                                                NaN
#
#                                                     title upload_date  \
# 0                      We Can Power The World With Algae!  2016-09-29
# 1                           How Poop Will Power The World  2013-09-15
# 2                              How First Impressions Work  2012-12-10
# 3                      Sony 8K Z9G Master Series Smart TV  2019-08-23
# 4          Bowers & Wilkins 600 Series Speaker Comparison  2019-08-13
# ...                                                   ...         ...
# 178250             The Best Engineering Laptop!Mac or PC?  2018-07-08
# 178251  How to Install Windows 10 on Any Android Phone...  2018-10-20
# 178252    Best Video Player For Android Phone - Must Try!  2018-06-19
# 178253                           I PHONE 11MAX PRO REVIEW  2019-09-21
# 178254                              SAMSUNG S9 S9+ REVIEW  2018-03-09
#
#         view_count  num_comms  \
# 0         235974.0      700.0
# 1          92531.0      465.0
# 2         164020.0      248.0
# 3           2585.0       12.0
# 4           5974.0       19.0
# ...            ...        ...
# 178250     42628.0       79.0
# 178251      2723.0        7.0
# 178252       897.0        0.0
# 178253        54.0        0.0
# 178254       128.0        0.0
#
#                                               clean_title  \
# 0                             ['power', 'world', 'algae']
# 1                              ['poop', 'power', 'world']
# 2                         ['first', 'impression', 'work']
# 3             ['sony', 'master', 'series', 'smart', 'tv']
# 4       ['bower', 'wilkins', 'series', 'speaker', 'com...
# ...                                                   ...
# 178250     ['best', 'engineering', 'laptop', 'mac', 'pc']
# 178251          ['install', 'window', 'android', 'phone']
# 178252  ['best', 'video', 'player', 'android', 'phone'...
# 178253                  ['phone', 'max', 'pro', 'review']
# 178254                              ['samsung', 'review']
#
#                                                clean_tags
# 0       ['current', 'event', 'science', 'biofuel', 'al...
# 1       ['energy', 'dimension', 'testtube', 'fertilize...
# 2       ['social', 'networking', 'first', 'impression'...
# 3       ['sony', 'sony', 'tv', 'sony', 'television', '...
# 4       ['bower', 'wilkins', 'bower', 'wilkins', 'cent...
# ...                                                   ...
# 178250  ['surface', 'book', 'best', 'laptop', 'enginee...
# 178251  ['install', 'window', 'android', 'phone', 'win...
# 178252  ['best', 'video', 'player', 'android', 'video'...
# 178253                                                 []
# 178254                                                 []
#
# [178255 rows x 12 columns]

# %%
df_vd_tech_modif = df_vd_tech.copy() 
#change upload_date from str to datetime type
df_vd_tech_modif["upload_date"] = df_vd_tech_modif.apply(lambda x: x["upload_date"].strftime("%Y"), axis=1)

# %%
df_vd_tech_modif
# Out:
#                       channel_id  dislike_count   display_id  duration  \
# 0       UCzWQYUVCpZqtN93H8RR44Qw           87.0  ExOXF1x3N1g       292
# 1       UCzWQYUVCpZqtN93H8RR44Qw           36.0  _RhHuW2gglw       193
# 2       UCzWQYUVCpZqtN93H8RR44Qw           34.0  g513EUHqkfw       191
# 3       UCzVy1DW9NFp4c910hMd_jIw            1.0  fRY3dpFBF14       217
# 4       UCzVy1DW9NFp4c910hMd_jIw            3.0  VenwYvLRa-I       437
# ...                          ...            ...          ...       ...
# 178250  UCrwT2LIOntbglCR2o0iOXVw           20.0  WjcXvzzRB0M       196
# 178251  UCrwPkTBuhZJDgiHkWzY7COw           35.0  UySYfgQaIlo       200
# 178252  UCrwPkTBuhZJDgiHkWzY7COw            0.0  lqpuuKkh-lA       226
# 178253  UCrwMvZOgSvS2srsIjY-iIGg            0.0  7uFD7TYwlW4       182
# 178254  UCrwMvZOgSvS2srsIjY-iIGg            0.0  OuwVfKw_7Y4        30
#
#         like_count                                               tags  \
# 0           7386.0  current events,Science,biofuel,algae,power,Bio...
# 1           1933.0  Energy (Dimension),testtube,fertilizer,human w...
# 2           2556.0  social,networking,first impressions,judge,meet...
# 3             72.0  Sony,8K,Sony 8K,TV,2019 Sony 8K,8K Television,...
# 4            107.0  Bowers and Wilkins,B&W,Bowers,Wilkins,603,606,...
# ...            ...                                                ...
# 178250       486.0  surface book,best laptop for engineering,elect...
# 178251        31.0  how to install windows 10 on android phone,win...
# 178252        11.0  Best Video player for Android,video player,vid...
# 178253         7.0                                                NaN
# 178254         2.0                                                NaN
#
#                                                     title upload_date  \
# 0                      We Can Power The World With Algae!        2016
# 1                           How Poop Will Power The World        2013
# 2                              How First Impressions Work        2012
# 3                      Sony 8K Z9G Master Series Smart TV        2019
# 4          Bowers & Wilkins 600 Series Speaker Comparison        2019
# ...                                                   ...         ...
# 178250             The Best Engineering Laptop!Mac or PC?        2018
# 178251  How to Install Windows 10 on Any Android Phone...        2018
# 178252    Best Video Player For Android Phone - Must Try!        2018
# 178253                           I PHONE 11MAX PRO REVIEW        2019
# 178254                              SAMSUNG S9 S9+ REVIEW        2018
#
#         view_count  num_comms  \
# 0         235974.0      700.0
# 1          92531.0      465.0
# 2         164020.0      248.0
# 3           2585.0       12.0
# 4           5974.0       19.0
# ...            ...        ...
# 178250     42628.0       79.0
# 178251      2723.0        7.0
# 178252       897.0        0.0
# 178253        54.0        0.0
# 178254       128.0        0.0
#
#                                               clean_title  \
# 0                             ['power', 'world', 'algae']
# 1                              ['poop', 'power', 'world']
# 2                         ['first', 'impression', 'work']
# 3             ['sony', 'master', 'series', 'smart', 'tv']
# 4       ['bower', 'wilkins', 'series', 'speaker', 'com...
# ...                                                   ...
# 178250     ['best', 'engineering', 'laptop', 'mac', 'pc']
# 178251          ['install', 'window', 'android', 'phone']
# 178252  ['best', 'video', 'player', 'android', 'phone'...
# 178253                  ['phone', 'max', 'pro', 'review']
# 178254                              ['samsung', 'review']
#
#                                                clean_tags
# 0       ['current', 'event', 'science', 'biofuel', 'al...
# 1       ['energy', 'dimension', 'testtube', 'fertilize...
# 2       ['social', 'networking', 'first', 'impression'...
# 3       ['sony', 'sony', 'tv', 'sony', 'television', '...
# 4       ['bower', 'wilkins', 'bower', 'wilkins', 'cent...
# ...                                                   ...
# 178250  ['surface', 'book', 'best', 'laptop', 'enginee...
# 178251  ['install', 'window', 'android', 'phone', 'win...
# 178252  ['best', 'video', 'player', 'android', 'video'...
# 178253                                                 []
# 178254                                                 []
#
# [178255 rows x 12 columns]

# %% [markdown]
# ## 1. Video statistics

# %%
df_vd_tech_modif_likes = df_vd_tech_modif.groupby("upload_date")[["like_count"]].mean()
df_vd_tech_modif_likes.columns = ["average_number_of_likes"]

# %%
# Plot : Average video duration per year
# Set up the subplots with the figure size (14,4)
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(14, 4))
sns.pointplot(x=df_vd_tech_modif_likes.index,
              y='average_number_of_likes',
              errwidth=1.5,
              data=df_vd_tech_modif_likes,
              ax=axes,
              color='#005AB5')
axes.set_title('Average number of likes per video per year')
axes.set_ylabel('Average number of likes')
axes.set_xlabel('Year')
axes.grid(axis='y', linestyle='--')

# %%
df_vd_tech_modif_dislikes = df_vd_tech_modif.groupby("upload_date")[["dislike_count"]].mean()
df_vd_tech_modif_dislikes.columns = ["average_number_of_dislikes"]

# %%
# Plot : Average video duration per year
# Set up the subplots with the figure size (14,4)
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(14, 4))
sns.pointplot(x=df_vd_tech_modif_dislikes.index,
              y='average_number_of_dislikes',
              errwidth=1.5,
              data=df_vd_tech_modif_dislikes,
              ax=axes,
              color='#005AB5')
axes.set_title('Average number of dislikes per video per year')
axes.set_ylabel('Average number of dislikes')
axes.set_xlabel('Year')
axes.grid(axis='y', linestyle='--')

# %%
df_vd_tech_modif_duration = df_vd_tech_modif.groupby("upload_date")[["duration"]].mean()

# %%
df_vd_tech_modif_duration.columns = ["average_duration"]

# %%
# Plot : Average video duration per year
# Set up the subplots with the figure size (14,4)
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(14, 4))
sns.pointplot(x=df_vd_tech_modif_duration.index,
              y='average_duration',
              errwidth=1.5,
              data=df_vd_tech_modif_duration,
              ax=axes,
              color='#005AB5')
axes.set_title('Average video duration per year')
axes.set_ylabel('Average duration (in seconds)')
axes.set_xlabel('Year')
axes.grid(axis='y', linestyle='--')

# %%
sns.boxplot(x=df_vd_tech["duration"])
# Out:
# <Axes: xlabel='duration'>

# %%
#remove all videos that have 0 view count to be able to compute the like_count_ratio later on 
df_vd_tech_filtered = df_vd_tech_modif[df_vd_tech_modif["view_count"]!=0]

# %%
#correlation between like count and duration
df_vd_tech_filtered["like_count_ratio"] = df_vd_tech_filtered['like_count']/df_vd_tech_filtered["view_count"]
pearson_like_duration_corrs = []
spearmanr_like_duration_corrs = []

years = np.unique(df_vd_tech_filtered["upload_date"])
for year in years:
    corr = stats.pearsonr(df_vd_tech_filtered["upload_yea"].dropna()["duration"], df_vd_tech_filtered.dropna()['like_count_ratio'])
    pearson_like_duration_corrs.append(corr)
    corr = stats.spearmanr(df_vd_tech_filtered.dropna()["duration"], df_vd_tech_filtered.dropna()['like_count_ratio'])
    spearmanr_like_duration_corrs.append(corr)
# Out:
# C:\Users\Zied\AppData\Local\Temp\ipykernel_31372\3998901061.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vd_tech_filtered["like_count_ratio"] = df_vd_tech_filtered['like_count']/df_vd_tech_filtered["view_count"]

# %%
df_corrs_pearson = pd.DataFrame(pearson_like_duration_corrs, columns=["pearson_corr", "p_value"], index=years)

# %%
df_corrs_pearson
# Out:
#       pearson_corr        p_value
# 2006      0.060726  7.573366e-139
# 2007      0.060726  7.573366e-139
# 2008      0.060726  7.573366e-139
# 2009      0.060726  7.573366e-139
# 2010      0.060726  7.573366e-139
# 2011      0.060726  7.573366e-139
# 2012      0.060726  7.573366e-139
# 2013      0.060726  7.573366e-139
# 2014      0.060726  7.573366e-139
# 2015      0.060726  7.573366e-139
# 2016      0.060726  7.573366e-139
# 2017      0.060726  7.573366e-139
# 2018      0.060726  7.573366e-139
# 2019      0.060726  7.573366e-139

# %%
sns.barplot(df_corrs_pearson, x=df_corrs_pearson.index, y="pearson_corr")
# Out:
# <Axes: ylabel='pearson_corr'>

# %%
df_corrs_spearman = pd.DataFrame(spearmanr_like_duration_corrs, columns=["spearman_corr", "p_value"], index=years)

# %%
df_corrs_spearman
# Out:
#       spearman_corr  p_value
# 2006       0.202255      0.0
# 2007       0.202255      0.0
# 2008       0.202255      0.0
# 2009       0.202255      0.0
# 2010       0.202255      0.0
# 2011       0.202255      0.0
# 2012       0.202255      0.0
# 2013       0.202255      0.0
# 2014       0.202255      0.0
# 2015       0.202255      0.0
# 2016       0.202255      0.0
# 2017       0.202255      0.0
# 2018       0.202255      0.0
# 2019       0.202255      0.0

# %%
sns.barplot(df_corrs_spearman, x=df_corrs_spearman.index, y="spearman_corr")
# Out:
# <Axes: ylabel='spearman_corr'>

# %% [markdown]
# There is a small (0.2), but significant (p < 0.05) positive correlation between the duration of a video and the number of likes it gets.

# %%
#correlation between dislike count and duration
df_vd_tech_filtered["dislike_count_ratio"] = df_vd_tech_filtered['dislike_count']/df_vd_tech_filtered["view_count"]
pearson_dislike_duration_corrs = []
spearmanr_dislike_duration_corrs = []

years = np.unique(df_vd_tech_filtered["upload_date"])
for year in years:
    corr = stats.pearsonr(df_vd_tech_filtered.dropna()["duration"], df_vd_tech_filtered.dropna()['dislike_count_ratio'])
    pearson_dislike_duration_corrs.append(corr)
    corr = stats.spearmanr(df_vd_tech_filtered.dropna()["duration"], df_vd_tech_filtered.dropna()['dislike_count_ratio'])
    spearmanr_dislike_duration_corrs.append(corr)
# Out:
# C:\Users\Zied\AppData\Local\Temp\ipykernel_31372\2609931737.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vd_tech_filtered["dislike_count_ratio"] = df_vd_tech_filtered['dislike_count']/df_vd_tech_filtered["view_count"]

# %%
df_corrs_pearson = pd.DataFrame(pearson_dislike_duration_corrs, columns=["pearson_corr", "p_value"], index=years)

# %%
df_corrs_pearson
# Out:
#       pearson_corr  p_value
# 2006      0.003561  0.14174
# 2007      0.003561  0.14174
# 2008      0.003561  0.14174
# 2009      0.003561  0.14174
# 2010      0.003561  0.14174
# 2011      0.003561  0.14174
# 2012      0.003561  0.14174
# 2013      0.003561  0.14174
# 2014      0.003561  0.14174
# 2015      0.003561  0.14174
# 2016      0.003561  0.14174
# 2017      0.003561  0.14174
# 2018      0.003561  0.14174
# 2019      0.003561  0.14174

# %%
sns.barplot(df_corrs_pearson, x=df_corrs_pearson.index, y="pearson_corr")
# Out:
# <Axes: ylabel='pearson_corr'>

# %%
df_corrs_spearman = pd.DataFrame(spearmanr_dislike_duration_corrs, columns=["spearman_corr", "p_value"], index=years)

# %%
df_corrs_spearman
# Out:
#       spearman_corr  p_value
# 2006       0.102307      0.0
# 2007       0.102307      0.0
# 2008       0.102307      0.0
# 2009       0.102307      0.0
# 2010       0.102307      0.0
# 2011       0.102307      0.0
# 2012       0.102307      0.0
# 2013       0.102307      0.0
# 2014       0.102307      0.0
# 2015       0.102307      0.0
# 2016       0.102307      0.0
# 2017       0.102307      0.0
# 2018       0.102307      0.0
# 2019       0.102307      0.0

# %%
sns.barplot(df_corrs_spearman, x=df_corrs_spearman.index, y="spearman_corr")
# Out:
# <Axes: ylabel='spearman_corr'>

# %% [markdown]
# There is a small (0.1), but significant (p < 0.05) positive correlation between the duration of a video and the number of dislikes it gets.

# %%
sample = df_vd_tech_filtered.sample(100)

# %%
plt.scatter(sample["duration"], sample['like_count_ratio'])
plt.title(
    'Scatter plot: likes vs duration of videos')
plt.ylabel('Ratio of likes')
plt.xlabel('Duration')
# Out:
# Text(0.5, 0, 'Duration')

# %%
plt.scatter(sample["duration"], sample['dislike_count_ratio'])
plt.title(
    'Scatter plot: dislikes vs duration of videos')
plt.ylabel('Ratio of dislikes')
plt.xlabel('Duration')
# Out:
# Text(0.5, 0, 'Duration')

# %%
# Examine the ratio of likes to dislikes for videos of different lengths. Are certain lengths more polarizing, 
#leading to a higher number of dislikes?

# %% [markdown]
# ## Views, Videos, Likes, Duration

# %%
df_vd_cat_count = df_vd_f.groupby("categories").sum()
df_vd_cat_count = df_vd_cat_count.drop(["", "Movies", "Shows"])
df_vd_cat_count[["dislike_count", "like_count"]] = df_vd_cat_count[["dislike_count", "like_count"]] / 1000000
df_vd_cat_count[["dummmy"]] = df_vd_cat_count[["dummmy"]] / 1000000
df_vd_cat_count[["view_count"]] = df_vd_cat_count[["view_count"]] / 1000000000
df_vd_cat_count[["duration"]] = df_vd_cat_count[["duration"]] / 3.154e+7
tmp = df_vd_cat_count.rename({"dislike_count": "# Dislikes (M)",
    "duration": "Duration (Years)",
    "like_count": "# Likes (M)",
    "view_count": "# Views (B)",
    "dummmy": "# Videos (M)"
    }, axis=1)[["# Views (B)", "# Videos (M)", "# Likes (M)", "Duration (Years)"]]
display(tmp)
# Out:
#                        # Views (B)  # Videos (M)   # Likes (M)  \
# categories
# Autos & Vehicles        123.094344      2.256967    956.300323
# Comedy                  345.039111      1.172503   6134.162539
# Education               502.391835      3.795564   2881.361591
# Entertainment          2287.747785     12.276397  20140.552867
# Film & Animation        576.280807      2.359736   3737.846598
# Gaming                 1042.503030     13.720303  17351.327104
# Howto & Style           420.666785      3.968127   5790.819053
# Music                  2474.987208      8.305003  19270.464688
# News & Politics         158.642354      8.881022   1892.882798
# Nonprofits & Activism    18.508415      0.777449    242.948972
# People & Blogs          617.343103      6.910666   9138.068304
# Pets & Animals           72.076164      0.645508    659.841475
# Science & Technology    175.003323      2.403004   1978.449383
# Sports                  262.006516      4.354412   2528.111024
# Travel & Events          56.393865      1.096565    459.804581
#
#                        Duration (Years)
# categories
# Autos & Vehicles              27.034161
# Comedy                        18.926862
# Education                    117.080173
# Entertainment                243.069061
# Film & Animation              47.726916
# Gaming                       623.167983
# Howto & Style                 73.645316
# Music                        124.088194
# News & Politics              144.766513
# Nonprofits & Activism         29.490161
# People & Blogs               148.848377
# Pets & Animals                 9.905389
# Science & Technology          47.514995
# Sports                        77.309024
# Travel & Events               19.239761

# %%
#naive bayes classifier with laplace-smoothing
def naive_bayes(dict_good, dict_bad, title):
    '''dict_good: python dict, contains, as keys, all words from the tech review videos' titles (smoothed; i.e. we add to it all words
    that aren't initially in it but are among words in all titles when considering all videos) and, as values, the frequency of the word
    (probability; i.e. # of occurences of the word/(# of occurences of all words + smoothing factor*N)); for words that weren't initially present, 
    we assign to them smoothing factor/(# of occurences of all words + smoothing factor*N)
    smoothing factor is chosen to be 1. 
    N is the number of words that are added (initially not among the words from the titles of tech review videos)
    
    dict_bad: same idea as dict good, but contains all other words that aren't in the titles of tech review videos (also smoothed) 
    title: list: the words of the title of a video to which we want to get its score
    
    returns: 
    title's score; we can compare this score to 0.5, if it's larger then it's likely "good" else it's considered "bad"
    '''
    
    proba_good = np.sum(list(dict_good.values()))/(np.sum(list(dict_good.values()))+np.sum(list(dict_bad.values())))
    proba_bad = np.sum(list(dict_bad.values()))/(np.sum(list(dict_good.values()))+np.sum(list(dict_bad.values())))
    
    prob_title_given_good = 1
    prob_title_given_bad = 1
    for w in title:
        prob_title_given_good *= dict_good[w]
        prob_title_given_bad *= dict_bad[w]
        
    score = (prob_title_given_good * proba_good)/(prob_title_given_good * proba_good + prob_title_given_bad * proba_bad)
    
    return score
