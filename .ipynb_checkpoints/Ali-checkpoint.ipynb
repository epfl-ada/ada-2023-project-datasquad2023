# %% [markdown]
# # Best time to release review after tech event

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import re
import datetime
import matplotlib.pyplot as plt

# %%
PATH_YT_METADATA = 'data/yt_metadata_en.jsonl'
ITEMS = ['iphone x', 'iphone 7', 'iphone 6', 'galaxy s9', 'galaxy note 9', 'galaxy fold']
RELEASE_DATES = {
    'iphone x': '2017-11-03',
    'iphone 7': '2016-09-16',
    'iphone 6': '2014-09-19',
    'galaxy s9': '2018-03-16',
    'galaxy note 9': '2018-08-24',
    'galaxy fold': '2019-02-01'
}

# %%
items_dfs = {k : [] for k in ITEMS}

# %%
# filter metadata
total_rows = 72924794
chunksize = 100000
for df_json in tqdm(pd.read_json(PATH_YT_METADATA, compression="infer", lines=True, chunksize=chunksize), desc='Loading data', total=total_rows/chunksize):
    df_json.drop(["description", "crawl_date", "display_id", "tags"], inplace=True, axis=1)
    df_json = df_json[df_json['categories'].isin(['Science & Technology', 'Education', 'Entertainment'])]
    df_json.drop(["categories"], inplace=True, axis=1)
    for item in ITEMS:
        df_item = df_json[df_json['title'].str.lower().str.contains(item)]
        df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
        df_item = df_item[(df_item['upload_date'] >= datetime.datetime.strptime(RELEASE_DATES[item], '%Y-%m-%d') - datetime.timedelta(days=180)) & (df_item['upload_date'] <= datetime.datetime.strptime(RELEASE_DATES[item], '%Y-%m-%d') + datetime.timedelta(days=180))]
        if len(df_item) > 0:
            items_dfs[item].append(df_item)
# yt_metadata.to_pickle(PATH_YT_TECH_METADATA,compression='gzip')
# Out:
# Loading data:   0%|          | 0/729.24794 [00:00<?, ?it/s]
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   0%|          | 1/729.24794 [00:00<08:45,  1.38it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   0%|          | 2/729.24794 [00:01<08:38,  1.40it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   0%|          | 3/729.24794 [00:02<08:45,  1.38it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   1%|          | 4/729.24794 [00:02<08:38,  1.40it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   1%|          | 5/729.24794 [00:03<08:21,  1.44it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   1%|          | 6/729.24794 [00:04<08:09,  1.48it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   1%|          | 7/729.24794 [00:04<08:11,  1.47it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   1%|          | 8/729.24794 [00:05<08:04,  1.49it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   1%|          | 9/729.24794 [00:06<08:19,  1.44it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   1%|▏         | 10/729.24794 [00:06<08:26,  1.42it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   2%|▏         | 11/729.24794 [00:07<08:21,  1.43it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   2%|▏         | 12/729.24794 [00:08<08:21,  1.43it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   2%|▏         | 13/729.24794 [00:09<08:33,  1.40it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   2%|▏         | 14/729.24794 [00:09<08:38,  1.38it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   2%|▏         | 15/729.24794 [00:10<08:23,  1.42it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   2%|▏         | 16/729.24794 [00:11<08:20,  1.42it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   2%|▏         | 17/729.24794 [00:11<08:32,  1.39it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   2%|▏         | 18/729.24794 [00:12<08:38,  1.37it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   3%|▎         | 19/729.24794 [00:13<08:32,  1.39it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   3%|▎         | 20/729.24794 [00:14<08:21,  1.42it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   3%|▎         | 21/729.24794 [00:14<08:22,  1.41it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   3%|▎         | 22/729.24794 [00:15<08:17,  1.42it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:   3%|▎         | 23/729.24794 [00:16<08:40,  1.36it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:  99%|█████████▉| 721/729.24794 [08:49<00:06,  1.31it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:  99%|█████████▉| 722/729.24794 [08:50<00:05,  1.29it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# Loading data:  99%|█████████▉| 723/729.24794 [08:51<00:04,  1.27it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:  99%|█████████▉| 724/729.24794 [08:51<00:04,  1.28it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data:  99%|█████████▉| 725/729.24794 [08:52<00:03,  1.33it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data: 100%|█████████▉| 726/729.24794 [08:53<00:02,  1.31it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# Loading data: 100%|█████████▉| 727/729.24794 [08:54<00:01,  1.32it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data: 100%|█████████▉| 728/729.24794 [08:54<00:00,  1.37it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# /var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_item["upload_date"] = pd.to_datetime(df_item["upload_date"])
# Loading data: 100%|█████████▉| 729/729.24794 [08:55<00:00,  1.41it/s]/var/folders/zj/sr110gkn1vz4qf70llfwlh8c0000gn/T/ipykernel_1771/2882069087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_json.drop(["categories"], inplace=True, axis=1)
# Loading data: 730it [08:55,  1.36it/s]

# %%
items_dfs = {k : pd.concat(v) for k, v in items_dfs.items()}

# %%
import pickle
with open('data/yt_tech_metadata.pickle', 'wb') as f:
    pickle.dump(items_dfs, f)

# %%
for item in ITEMS:
    print(len(items_dfs[item]))
# Out:
# 5388
# 4456
# 3856
# 3882
# 2293
# 596

# %%
def get_avg_views(df):
    df["upload_date"] = pd.to_datetime(df["upload_date"])
    df["upload_date"] = df["upload_date"].dt.date

    # convert 'view_count' to int
    df["view_count"] = df["view_count"].astype(int)

    # keep only 'view_count' and 'upload_date'
    df = df[["view_count", "upload_date"]]
    df = df.groupby("upload_date").max()
    
    return df

# %%
def plot_views_per_day(df, item):
    plt.figure(figsize=(20,10))
    plt.bar(df.index, df["view_count"])
    plt.xlabel("Date")
    plt.ylabel("View Count")
    plt.title("{item} View Count Over Time".format(item=item))
    plt.show()

# %%
for item in ITEMS:
    df = get_avg_views(items_dfs[item])
    plot_views_per_day(df, item)
