# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import re
import datetime
import seaborn as sns
import pickle
import gzip
import matplotlib.pyplot as plt

# %% [markdown]
# The aim of this notebook is to identify the channels that talk about a release event to analyze their evolution in terms of the number of subscribers compared to those that do not talk about the event. First, we focus on 1 event, the release of the iPhone x. Then, we will generalize to the 5 others. From the title and tags of the videos, we classify them according to the presence of the item "iPhone x" in this metadata : treat,if talks about the release, control if not. We focus on videos that have an upload date from the release till one month later.
# Then, we classify the channels considering that if a channel has at least one video that talks about the release,then it is a treat channel.
# We compare the growth of channels (measured in terms of the number of subscribers) for treat and control channels to see if channels that talk about a release have a higher growth than the ones that do not. To do this comparison, we use the time series data and focus on a period that goes from 15 days before the release till 15 days after.
# Then, we will do an observational study (causal analysis) with the outcome being the number of subscribers while identifying the potential confounders.
# We first, focus on 1 event "iPhone x"

# %% [markdown]
# 1. classify channels in the treat/control group,
# 2. causal observation (like lab 5) with outcome being the nb of subscribers one month after the event

# %% [markdown]
# ### Channels' classification

# %%
tech_video_metadata = "/Users/salma/Desktop/ADA/project/datasets/tech_review_videos.tsv.gz"
tech_channels_metadata = "/Users/salma/Desktop/ADA/project/datasets/tech_review_channels.tsv.gz"

# %%
ITEMS = ['iphone x', 'iphone 7', 'iphone 6', 'galaxy s9', 'galaxy note 9', 'galaxy fold']
RELEASE_DATES = {'iphone x': '2017-11-03','iphone 7': '2016-09-16','iphone 6': '2014-09-19',
    'galaxy s9': '2018-03-16',
   'galaxy note 9': '2018-08-24',
    'galaxy fold': '2019-02-01'
}

# %%
df_video = pd.read_table(tech_video_metadata)
df_channel = pd.read_table(tech_channels_metadata)

# %%
df_video
# Out:
#                       channel_id  dislike_count   display_id  duration  \
# 0       UCzWQYUVCpZqtN93H8RR44Qw           87.0  ExOXF1x3N1g       292
# 1       UCzWQYUVCpZqtN93H8RR44Qw           36.0  _RhHuW2gglw       193
# 2       UCzWQYUVCpZqtN93H8RR44Qw           34.0  g513EUHqkfw       191
# 3       UCzVy1DW9NFp4c910hMd_jIw            1.0  fRY3dpFBF14       217
# 4       UCzVy1DW9NFp4c910hMd_jIw            3.0  VenwYvLRa-I       437
# ...                          ...            ...          ...       ...
# 178250  UCrwT2LIOntbglCR2o0iOXVw           20.0  WjcXvzzRB0M       196
# 178251  UCrwPkTBuhZJDgiHkWzY7COw           35.0  UySYfgQaIlo       200
# 178252  UCrwPkTBuhZJDgiHkWzY7COw            0.0  lqpuuKkh-lA       226
# 178253  UCrwMvZOgSvS2srsIjY-iIGg            0.0  7uFD7TYwlW4       182
# 178254  UCrwMvZOgSvS2srsIjY-iIGg            0.0  OuwVfKw_7Y4        30
#
#         like_count                                               tags  \
# 0           7386.0  current events,Science,biofuel,algae,power,Bio...
# 1           1933.0  Energy (Dimension),testtube,fertilizer,human w...
# 2           2556.0  social,networking,first impressions,judge,meet...
# 3             72.0  Sony,8K,Sony 8K,TV,2019 Sony 8K,8K Television,...
# 4            107.0  Bowers and Wilkins,B&W,Bowers,Wilkins,603,606,...
# ...            ...                                                ...
# 178250       486.0  surface book,best laptop for engineering,elect...
# 178251        31.0  how to install windows 10 on android phone,win...
# 178252        11.0  Best Video player for Android,video player,vid...
# 178253         7.0                                                NaN
# 178254         2.0                                                NaN
#
#                                                     title upload_date  \
# 0                      We Can Power The World With Algae!  2016-09-29
# 1                           How Poop Will Power The World  2013-09-15
# 2                              How First Impressions Work  2012-12-10
# 3                      Sony 8K Z9G Master Series Smart TV  2019-08-23
# 4          Bowers & Wilkins 600 Series Speaker Comparison  2019-08-13
# ...                                                   ...         ...
# 178250             The Best Engineering Laptop!Mac or PC?  2018-07-08
# 178251  How to Install Windows 10 on Any Android Phone...  2018-10-20
# 178252    Best Video Player For Android Phone - Must Try!  2018-06-19
# 178253                           I PHONE 11MAX PRO REVIEW  2019-09-21
# 178254                              SAMSUNG S9 S9+ REVIEW  2018-03-09
#
#         view_count  num_comms  \
# 0         235974.0      700.0
# 1          92531.0      465.0
# 2         164020.0      248.0
# 3           2585.0       12.0
# 4           5974.0       19.0
# ...            ...        ...
# 178250     42628.0       79.0
# 178251      2723.0        7.0
# 178252       897.0        0.0
# 178253        54.0        0.0
# 178254       128.0        0.0
#
#                                               clean_title  \
# 0                             ['power', 'world', 'algae']
# 1                              ['poop', 'power', 'world']
# 2                         ['first', 'impression', 'work']
# 3             ['sony', 'master', 'series', 'smart', 'tv']
# 4       ['bower', 'wilkins', 'series', 'speaker', 'com...
# ...                                                   ...
# 178250     ['best', 'engineering', 'laptop', 'mac', 'pc']
# 178251          ['install', 'window', 'android', 'phone']
# 178252  ['best', 'video', 'player', 'android', 'phone'...
# 178253                  ['phone', 'max', 'pro', 'review']
# 178254                              ['samsung', 'review']
#
#                                                clean_tags
# 0       ['current', 'event', 'science', 'biofuel', 'al...
# 1       ['energy', 'dimension', 'testtube', 'fertilize...
# 2       ['social', 'networking', 'first', 'impression'...
# 3       ['sony', 'sony', 'tv', 'sony', 'television', '...
# 4       ['bower', 'wilkins', 'bower', 'wilkins', 'cent...
# ...                                                   ...
# 178250  ['surface', 'book', 'best', 'laptop', 'enginee...
# 178251  ['install', 'window', 'android', 'phone', 'win...
# 178252  ['best', 'video', 'player', 'android', 'video'...
# 178253                                                 []
# 178254                                                 []
#
# [178255 rows x 12 columns]

# %%
df_channel
# Out:
#        join_date                channel_id                  name_cc  \
# 0     2010-12-21  UCsTcErHg8oDvUnTzoqsYeNw            Unbox Therapy
# 1     2015-10-19  UCOhHO2ICt0ti9KAh-QHvttQ         Technical Guruji
# 2     2012-05-18  UCe_vXdMrHHseZ_esYUskSBw       CrazyRussianHacker
# 3     2005-06-22  UCE_M8A5yxnLfW0KghEeajjw                    Apple
# 4     2008-03-21  UCBJycsmduvYEL83R_U4JriQ         Marques Brownlee
# ...          ...                       ...                      ...
# 1188  2012-06-06  UCgMHqEDFll6X962CgXPzh4w           FocusCamera TV
# 1189  2018-02-25  UCJjacdkHH7Zxw8ouKQrirUg          The Best Coders
# 1190  2016-07-17  UCviAcL8AlEoGqLDWx7t_iPw               Mobile Tag
# 1191  2011-02-20  UCncAHfjOv1B_U8esTmLYukQ           Curtis Paradis
# 1192  2010-08-21  UCqcOdYkYBroLwnaKPWVdNRA  LavcoPriceIndustries...
#
#       subscribers_cc  videos_cc  subscriber_rank_sb  weights  \
# 0           15300000       1672               206.0   2.0870
# 1           13979890       2539               240.0   2.0870
# 2           11200000       1411               444.0   2.0870
# 3            9970000        291               489.0   2.0870
# 4            9400000       1148               530.0   2.0870
# ...              ...        ...                 ...      ...
# 1188           10000        278            940963.0  40.6530
# 1189           10200         28            941074.0  42.4845
# 1190           10300         20            952387.0  53.1435
# 1191           10300         97            963290.0  53.1435
# 1192           10100       1616            963759.0  53.1435
#
#       count_tech_videos
# 0                 406.0
# 1                 209.0
# 2                 105.0
# 3                  64.0
# 4                 370.0
# ...                 ...
# 1188               42.0
# 1189                2.0
# 1190                6.0
# 1191               11.0
# 1192              226.0
#
# [1193 rows x 8 columns]

# %%
df_video_cop = df_video.copy()
df_channel_cop = df_channel.copy()
# we merge the channels and video's metadata in a single dataframe
df_merged = df_video_cop.merge(df_channel_cop,on=['channel_id'],how ='left')
# we create a new column with the treat attribute being set to 1 if the video talks about the release, 0 otherwise
df_merged["treat"]= 0

# %%
#we transform all the titles and tags to lower case to look for the item's name
df_merged["tags"] = df_merged["tags"].str.lower()
df_merged["title"]= df_merged["title"].str.lower()
df_merged
# Out:
#                       channel_id  dislike_count   display_id  duration  \
# 0       UCzWQYUVCpZqtN93H8RR44Qw           87.0  ExOXF1x3N1g       292
# 1       UCzWQYUVCpZqtN93H8RR44Qw           36.0  _RhHuW2gglw       193
# 2       UCzWQYUVCpZqtN93H8RR44Qw           34.0  g513EUHqkfw       191
# 3       UCzVy1DW9NFp4c910hMd_jIw            1.0  fRY3dpFBF14       217
# 4       UCzVy1DW9NFp4c910hMd_jIw            3.0  VenwYvLRa-I       437
# ...                          ...            ...          ...       ...
# 178250  UCrwT2LIOntbglCR2o0iOXVw           20.0  WjcXvzzRB0M       196
# 178251  UCrwPkTBuhZJDgiHkWzY7COw           35.0  UySYfgQaIlo       200
# 178252  UCrwPkTBuhZJDgiHkWzY7COw            0.0  lqpuuKkh-lA       226
# 178253  UCrwMvZOgSvS2srsIjY-iIGg            0.0  7uFD7TYwlW4       182
# 178254  UCrwMvZOgSvS2srsIjY-iIGg            0.0  OuwVfKw_7Y4        30
#
#         like_count                                               tags  \
# 0           7386.0  current events,science,biofuel,algae,power,bio...
# 1           1933.0  energy (dimension),testtube,fertilizer,human w...
# 2           2556.0  social,networking,first impressions,judge,meet...
# 3             72.0  sony,8k,sony 8k,tv,2019 sony 8k,8k television,...
# 4            107.0  bowers and wilkins,b&w,bowers,wilkins,603,606,...
# ...            ...                                                ...
# 178250       486.0  surface book,best laptop for engineering,elect...
# 178251        31.0  how to install windows 10 on android phone,win...
# 178252        11.0  best video player for android,video player,vid...
# 178253         7.0                                                NaN
# 178254         2.0                                                NaN
#
#                                                     title upload_date  \
# 0                      we can power the world with algae!  2016-09-29
# 1                           how poop will power the world  2013-09-15
# 2                              how first impressions work  2012-12-10
# 3                      sony 8k z9g master series smart tv  2019-08-23
# 4          bowers & wilkins 600 series speaker comparison  2019-08-13
# ...                                                   ...         ...
# 178250             the best engineering laptop!mac or pc?  2018-07-08
# 178251  how to install windows 10 on any android phone...  2018-10-20
# 178252    best video player for android phone - must try!  2018-06-19
# 178253                           i phone 11max pro review  2019-09-21
# 178254                              samsung s9 s9+ review  2018-03-09
#
#         view_count  num_comms  \
# 0         235974.0      700.0
# 1          92531.0      465.0
# 2         164020.0      248.0
# 3           2585.0       12.0
# 4           5974.0       19.0
# ...            ...        ...
# 178250     42628.0       79.0
# 178251      2723.0        7.0
# 178252       897.0        0.0
# 178253        54.0        0.0
# 178254       128.0        0.0
#
#                                               clean_title  \
# 0                             ['power', 'world', 'algae']
# 1                              ['poop', 'power', 'world']
# 2                         ['first', 'impression', 'work']
# 3             ['sony', 'master', 'series', 'smart', 'tv']
# 4       ['bower', 'wilkins', 'series', 'speaker', 'com...
# ...                                                   ...
# 178250     ['best', 'engineering', 'laptop', 'mac', 'pc']
# 178251          ['install', 'window', 'android', 'phone']
# 178252  ['best', 'video', 'player', 'android', 'phone'...
# 178253                  ['phone', 'max', 'pro', 'review']
# 178254                              ['samsung', 'review']
#
#                                                clean_tags   join_date  \
# 0       ['current', 'event', 'science', 'biofuel', 'al...         NaN
# 1       ['energy', 'dimension', 'testtube', 'fertilize...         NaN
# 2       ['social', 'networking', 'first', 'impression'...         NaN
# 3       ['sony', 'sony', 'tv', 'sony', 'television', '...  2010-10-11
# 4       ['bower', 'wilkins', 'bower', 'wilkins', 'cent...  2010-10-11
# ...                                                   ...         ...
# 178250  ['surface', 'book', 'best', 'laptop', 'enginee...         NaN
# 178251  ['install', 'window', 'android', 'phone', 'win...         NaN
# 178252  ['best', 'video', 'player', 'android', 'video'...         NaN
# 178253                                                 []         NaN
# 178254                                                 []         NaN
#
#              name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  weights  \
# 0                NaN             NaN        NaN                 NaN      NaN
# 1                NaN             NaN        NaN                 NaN      NaN
# 2                NaN             NaN        NaN                 NaN      NaN
# 3       Audio Advice         19500.0      199.0            416394.0   8.1235
# 4       Audio Advice         19500.0      199.0            416394.0   8.1235
# ...              ...             ...        ...                 ...      ...
# 178250           NaN             NaN        NaN                 NaN      NaN
# 178251           NaN             NaN        NaN                 NaN      NaN
# 178252           NaN             NaN        NaN                 NaN      NaN
# 178253           NaN             NaN        NaN                 NaN      NaN
# 178254           NaN             NaN        NaN                 NaN      NaN
#
#         count_tech_videos  treat
# 0                     NaN      0
# 1                     NaN      0
# 2                     NaN      0
# 3                    25.0      0
# 4                    25.0      0
# ...                   ...    ...
# 178250                NaN      0
# 178251                NaN      0
# 178252                NaN      0
# 178253                NaN      0
# 178254                NaN      0
#
# [178255 rows x 20 columns]

# %%
# we filter to focus on videos uploaded from the release date till 1 month after.
df_merged = df_merged.loc[(df_merged["upload_date"] > '2017-11-03')& (df_merged["upload_date"] <'2017-12-03')]

# %%
display(df_merged)
# Out:
#                       channel_id  dislike_count   display_id  duration  \
# 33      UCzV07t6mx27AcEPmpAUJYXw            3.0  2g3ykHWEOsI       338
# 34      UCzV07t6mx27AcEPmpAUJYXw           86.0  HWMm3ERfFCs       324
# 35      UCzV07t6mx27AcEPmpAUJYXw           45.0  6xVfMLhsdRc       585
# 36      UCzV07t6mx27AcEPmpAUJYXw            9.0  EWfSia7qNqI       139
# 37      UCzV07t6mx27AcEPmpAUJYXw            3.0  lFD3YQgZC-o       478
# ...                          ...            ...          ...       ...
# 177760  UCsCex8aMDs2b39TS_49Mpcg           17.0  MZk2ctF6tpI       714
# 177898  UCs7qwxT0HL2fLTtVrt4i45w            4.0  EgQUk0DBs_c       286
# 177966  UCs6KfncB4OV6Vug4o_bzijg           25.0  Y3HwTwYliwY       484
# 177978  UCs11Yv5OnpY_b3Bff5ZJ9kw          564.0  PcgcD8HQb0M       383
# 178120  UCrzySfCZIMqhYlDsDqtpQ6w            3.0  dqdYdN2BVD8        57
#
#         like_count                                               tags  \
# 33            28.0  rhino slider,rhino slider review,youtube video...
# 34           142.0  overhead camera,overhead camera mount,overhead...
# 35           256.0  google home mini,google home mini unboxing ind...
# 36            24.0  soumendra jena,sj,sj channel,soamjena,apple ip...
# 37            63.0  iphone x review,iphone 10 review,iphone x full...
# ...            ...                                                ...
# 177760       551.0  lg v30 review,lg v30 vs note 8,lg v30 unboxing...
# 177898        66.0  how i plan out youtube videos,planning youtube...
# 177966       372.0  protonvpn free,protonvpn review,protonvpn,prot...
# 177978     19344.0  iphone,iphonex,unboxing,apple,jordyn,jordyn jones
# 178120        38.0     iphone,apple,iphone 8,gold,unboxing,256gb,peel
#
#                                                     title upload_date  \
# 33      the best motion camera slider for youtube videos!  2017-11-28
# 34       the best overhead camera rig for youtube videos!  2017-11-26
# 35          google home mini in india - unboxing & setup!  2017-11-19
# 36         how to remove the top notch on apple iphone x!  2017-11-11
# 37                  apple iphone x - the detailed review!  2017-11-11
# ...                                                   ...         ...
# 177760  the best review of the most under rated phone ...  2017-12-02
# 177898                      how i plan out youtube videos  2017-11-24
# 177966  protonvpn full complete review! the new best vpn?  2017-11-18
# 177978                 iphone x first impression/unboxing  2017-11-04
# 178120                       iphone 8 gold 256gb unboxing  2017-11-18
#
#         view_count  num_comms  \
# 33           805.0        3.0
# 34         21197.0       22.0
# 35         15527.0      157.0
# 36          1247.0        7.0
# 37          1300.0       63.0
# ...            ...        ...
# 177760     18241.0      142.0
# 177898      1766.0       19.0
# 177966     28321.0       98.0
# 177978    693417.0        0.0
# 178120      2503.0        5.0
#
#                                               clean_title  \
# 33      ['best', 'motion', 'camera', 'slider', 'youtub...
# 34      ['best', 'overhead', 'camera', 'rig', 'youtube...
# 35      ['google', 'home', 'mini', 'india', 'unboxing'...
# 36          ['remove', 'top', 'notch', 'apple', 'iphone']
# 37              ['apple', 'iphone', 'detailed', 'review']
# ...                                                   ...
# 177760               ['best', 'review', 'rated', 'phone']
# 177898                       ['plan', 'youtube', 'video']
# 177966  ['protonvpn', 'full', 'complete', 'review', 'n...
# 177978      ['iphone', 'first', 'impression', 'unboxing']
# 178120               ['iphone', 'gold', 'gb', 'unboxing']
#
#                                                clean_tags   join_date  \
# 33      ['rhino', 'slider', 'rhino', 'slider', 'review...         NaN
# 34      ['overhead', 'camera', 'overhead', 'camera', '...         NaN
# 35      ['google', 'home', 'mini', 'google', 'home', '...         NaN
# 36      ['soumendra', 'jena', 'sj', 'sj', 'channel', '...         NaN
# 37      ['iphone', 'review', 'iphone', 'review', 'ipho...         NaN
# ...                                                   ...         ...
# 177760  ['lg', 'review', 'lg', 'note', 'lg', 'unboxing...  2013-10-23
# 177898  ['plan', 'youtube', 'video', 'planning', 'yout...         NaN
# 177966  ['protonvpn', 'free', 'protonvpn', 'review', '...         NaN
# 177978  ['iphone', 'iphonex', 'unboxing', 'apple', 'jo...         NaN
# 178120  ['iphone', 'apple', 'iphone', 'gold', 'unboxin...         NaN
#
#                name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 33                 NaN             NaN        NaN                 NaN
# 34                 NaN             NaN        NaN                 NaN
# 35                 NaN             NaN        NaN                 NaN
# 36                 NaN             NaN        NaN                 NaN
# 37                 NaN             NaN        NaN                 NaN
# ...                ...             ...        ...                 ...
# 177760  Jonathan Casey         74300.0      560.0            192469.0
# 177898             NaN             NaN        NaN                 NaN
# 177966             NaN             NaN        NaN                 NaN
# 177978             NaN             NaN        NaN                 NaN
# 178120             NaN             NaN        NaN                 NaN
#
#         weights  count_tech_videos  treat
# 33          NaN                NaN      0
# 34          NaN                NaN      0
# 35          NaN                NaN      0
# 36          NaN                NaN      0
# 37          NaN                NaN      0
# ...         ...                ...    ...
# 177760    5.741              165.0      0
# 177898      NaN                NaN      0
# 177966      NaN                NaN      0
# 177978      NaN                NaN      0
# 178120      NaN                NaN      0
#
# [2366 rows x 20 columns]

# %%
# look for the item's name in the title 
df_merged.loc[df_merged["title"].str.contains("iphone x"),"treat"] = 1 
#example of display_id of video that talks about iphone x : lFD3YQgZC-o

# %%
# look for the item's name in the tags. Here, we need to pay attention to the missing values and 
df_merged.loc[df_merged["tags"].str.contains("iphone x",na=False),"treat"] = 1

# %%
display(df_merged.loc[df_merged['treat'] == 1])
# Out:
#                       channel_id  dislike_count   display_id  duration  \
# 36      UCzV07t6mx27AcEPmpAUJYXw            9.0  EWfSia7qNqI       139
# 37      UCzV07t6mx27AcEPmpAUJYXw            3.0  lFD3YQgZC-o       478
# 38      UCzV07t6mx27AcEPmpAUJYXw            2.0  O4AoiYxgEek       139
# 271     UCzLaQ6eeTVuAltzTrN7fzyg           49.0  j8N0_hpIbOg       371
# 272     UCzLaQ6eeTVuAltzTrN7fzyg          134.0  uD3jCBz-Wdk       595
# ...                          ...            ...          ...       ...
# 176040  UCsTcErHg8oDvUnTzoqsYeNw        30050.0  2fGXDFiFBhg       503
# 176041  UCsTcErHg8oDvUnTzoqsYeNw         2064.0  Rh_iWXRxIY4       365
# 176042  UCsTcErHg8oDvUnTzoqsYeNw         2555.0  0KcvQpRdCzQ       402
# 177760  UCsCex8aMDs2b39TS_49Mpcg           17.0  MZk2ctF6tpI       714
# 177978  UCs11Yv5OnpY_b3Bff5ZJ9kw          564.0  PcgcD8HQb0M       383
#
#         like_count                                               tags  \
# 36            24.0  soumendra jena,sj,sj channel,soamjena,apple ip...
# 37            63.0  iphone x review,iphone 10 review,iphone x full...
# 38            13.0  soumendra jena,sj,sj channel,soamjena,iphone x...
# 271          164.0  youtube tech guy,the android guy,cellphone,sma...
# 272          191.0  youtube tech guy,the android guy,cellphone,sma...
# ...            ...                                                ...
# 176040    307915.0  iphone x,iphone x review,iphone,review,apple i...
# 176041     39646.0  razer phone,razer,phone,speaker,razer phone sp...
# 176042     83347.0  oneplus 5t,oneplus 5t unboxing,oneplus 5t revi...
# 177760       551.0  lg v30 review,lg v30 vs note 8,lg v30 unboxing...
# 177978     19344.0  iphone,iphonex,unboxing,apple,jordyn,jordyn jones
#
#                                                     title upload_date  \
# 36         how to remove the top notch on apple iphone x!  2017-11-11
# 37                  apple iphone x - the detailed review!  2017-11-11
# 38      camera comparison : apple iphone x vs samsung s8+  2017-11-09
# 271      samsung gear fit 2 pro review - youtube tech guy  2017-12-01
# 272     pixel 2 xl review - one of the most disappoint...  2017-11-30
# ...                                                   ...         ...
# 176040                             don't buy the iphone x  2017-11-26
# 176041  how loud is the razer phone? (vs iphone x, pix...  2017-11-18
# 176042             oneplus 5t unboxing - is this the one?  2017-11-16
# 177760  the best review of the most under rated phone ...  2017-12-02
# 177978                 iphone x first impression/unboxing  2017-11-04
#
#         view_count  num_comms  \
# 36          1247.0        7.0
# 37          1300.0       63.0
# 38           338.0        7.0
# 271        25708.0       16.0
# 272         5828.0      103.0
# ...            ...        ...
# 176040  10912434.0    58602.0
# 176041   1293524.0     2945.0
# 176042   4779536.0     7205.0
# 177760     18241.0      142.0
# 177978    693417.0        0.0
#
#                                               clean_title  \
# 36          ['remove', 'top', 'notch', 'apple', 'iphone']
# 37              ['apple', 'iphone', 'detailed', 'review']
# 38      ['camera', 'comparison', 'apple', 'iphone', 's...
# 271     ['samsung', 'gear', 'fit', 'pro', 'review', 'y...
# 272     ['pixel', 'xl', 'review', 'one', 'disappointin...
# ...                                                   ...
# 176040                                  ['buy', 'iphone']
# 176041  ['loud', 'razer', 'phone', 'iphone', 'pixel', ...
# 176042                     ['oneplus', 'unboxing', 'one']
# 177760               ['best', 'review', 'rated', 'phone']
# 177978      ['iphone', 'first', 'impression', 'unboxing']
#
#                                                clean_tags   join_date  \
# 36      ['soumendra', 'jena', 'sj', 'sj', 'channel', '...         NaN
# 37      ['iphone', 'review', 'iphone', 'review', 'ipho...         NaN
# 38      ['soumendra', 'jena', 'sj', 'sj', 'channel', '...         NaN
# 271     ['youtube', 'tech', 'guy', 'android', 'guy', '...  2012-02-16
# 272     ['youtube', 'tech', 'guy', 'android', 'guy', '...  2012-02-16
# ...                                                   ...         ...
# 176040  ['iphone', 'iphone', 'review', 'iphone', 'revi...  2010-12-21
# 176041  ['razer', 'phone', 'razer', 'phone', 'speaker'...  2010-12-21
# 176042  ['oneplus', 'oneplus', 'unboxing', 'oneplus', ...  2010-12-21
# 177760  ['lg', 'review', 'lg', 'note', 'lg', 'unboxing...  2013-10-23
# 177978  ['iphone', 'iphonex', 'unboxing', 'apple', 'jo...         NaN
#
#                         name_cc  subscribers_cc  videos_cc  \
# 36                          NaN             NaN        NaN
# 37                          NaN             NaN        NaN
# 38                          NaN             NaN        NaN
# 271     The YouTube Tech Guy...        314000.0     3205.0
# 272     The YouTube Tech Guy...        314000.0     3205.0
# ...                         ...             ...        ...
# 176040            Unbox Therapy      15300000.0     1672.0
# 176041            Unbox Therapy      15300000.0     1672.0
# 176042            Unbox Therapy      15300000.0     1672.0
# 177760           Jonathan Casey         74300.0      560.0
# 177978                      NaN             NaN        NaN
#
#         subscriber_rank_sb  weights  count_tech_videos  treat
# 36                     NaN      NaN                NaN      1
# 37                     NaN      NaN                NaN      1
# 38                     NaN      NaN                NaN      1
# 271                56986.0    3.532             1040.0      1
# 272                56986.0    3.532             1040.0      1
# ...                    ...      ...                ...    ...
# 176040               206.0    2.087              406.0      1
# 176041               206.0    2.087              406.0      1
# 176042               206.0    2.087              406.0      1
# 177760            192469.0    5.741              165.0      1
# 177978                 NaN      NaN                NaN      1
#
# [665 rows x 20 columns]

# %%
df_mer_cop = df_merged.copy() 
# We group the videos by channel's id and do a summation on the treat attribute. 
#If this summation is strictly positive, then it is a treat channel.
new_df = df_mer_cop.groupby("channel_id",sort=False)["treat"].count()

# %%
print(new_df)
# Out:
# channel_id
# UCzV07t6mx27AcEPmpAUJYXw     6
# UCzMidCxMjmFPwwKulMxLzhA     1
# UCzLaQ6eeTVuAltzTrN7fzyg    16
# UCzKvLgtTMGjYOKNlh12b08w     9
# UCzJjUHizQfPYywqt1mSEMww     2
#                             ..
# UCsCex8aMDs2b39TS_49Mpcg     1
# UCs7qwxT0HL2fLTtVrt4i45w     1
# UCs6KfncB4OV6Vug4o_bzijg     1
# UCs11Yv5OnpY_b3Bff5ZJ9kw     1
# UCrzySfCZIMqhYlDsDqtpQ6w     1
# Name: treat, Length: 894, dtype: int64

# %%
#list of the channels
channel_list = df_mer_cop["channel_id"].values.tolist()
print(channel_list)
# Out:
# ['UCzV07t6mx27AcEPmpAUJYXw', 'UCzV07t6mx27AcEPmpAUJYXw', 'UCzV07t6mx27AcEPmpAUJYXw', 'UCzV07t6mx27AcEPmpAUJYXw', 'UCzV07t6mx27AcEPmpAUJYXw', 'UCzV07t6mx27AcEPmpAUJYXw', 'UCzMidCxMjmFPwwKulMxLzhA', 'UC
 'UCvlmHF_K6UpaoqTnTBonRsQ', 'UCnJriaofCXGuqniK5SIMinQ', 'UCOmcA3f_RrH6b9NmcNa4tdg', 'UCRkP7XY9_7kQ03A48XY0vVw', 'UCNSkIgYMLDX3tZDNWPnbrDw', 'UC7_uYbNuR63Z8jQmlrTzXiA', 'UCKcFpMSH5prRLDhRcd6UJrg', 'UC1hiI8TEoA0db5HhU4gbsUg', 'UCVlMUh4WsDQvOxCJJXmWwdw', 'UCCbiyCWjdC0CXau58zrPmdA', 'UCS9OE6KeXQ54nSMqhRx0_EQ', 'UCL-gguNpeqwbCWSh8M7ld_g', 'UCABwqCK6XMowQDwlIz00U ...

# %%
#With the list of treat channels, we transform the channel dataframe by adding the channel classification as treat/control
df_channel_cop = df_channel.copy()
df_channel_cop["treat"]= 0
display(df_channel_cop)
df_channel_cop.loc[df_channel_cop['channel_id'].isin(list_treat_channel),"treat"] = 1
# Out:
#        join_date                channel_id                  name_cc  \
# 0     2010-12-21  UCsTcErHg8oDvUnTzoqsYeNw            Unbox Therapy
# 1     2015-10-19  UCOhHO2ICt0ti9KAh-QHvttQ         Technical Guruji
# 2     2012-05-18  UCe_vXdMrHHseZ_esYUskSBw       CrazyRussianHacker
# 3     2005-06-22  UCE_M8A5yxnLfW0KghEeajjw                    Apple
# 4     2008-03-21  UCBJycsmduvYEL83R_U4JriQ         Marques Brownlee
# ...          ...                       ...                      ...
# 1188  2012-06-06  UCgMHqEDFll6X962CgXPzh4w           FocusCamera TV
# 1189  2018-02-25  UCJjacdkHH7Zxw8ouKQrirUg          The Best Coders
# 1190  2016-07-17  UCviAcL8AlEoGqLDWx7t_iPw               Mobile Tag
# 1191  2011-02-20  UCncAHfjOv1B_U8esTmLYukQ           Curtis Paradis
# 1192  2010-08-21  UCqcOdYkYBroLwnaKPWVdNRA  LavcoPriceIndustries...
#
#       subscribers_cc  videos_cc  subscriber_rank_sb  weights  \
# 0           15300000       1672               206.0   2.0870
# 1           13979890       2539               240.0   2.0870
# 2           11200000       1411               444.0   2.0870
# 3            9970000        291               489.0   2.0870
# 4            9400000       1148               530.0   2.0870
# ...              ...        ...                 ...      ...
# 1188           10000        278            940963.0  40.6530
# 1189           10200         28            941074.0  42.4845
# 1190           10300         20            952387.0  53.1435
# 1191           10300         97            963290.0  53.1435
# 1192           10100       1616            963759.0  53.1435
#
#       count_tech_videos  treat
# 0                 406.0      0
# 1                 209.0      0
# 2                 105.0      0
# 3                  64.0      0
# 4                 370.0      0
# ...                 ...    ...
# 1188               42.0      0
# 1189                2.0      0
# 1190                6.0      0
# 1191               11.0      0
# 1192              226.0      0
#
# [1193 rows x 9 columns]

# %%
#dataframe of tech channels classified as treat or control
display(df_channel_cop)
# Out:
#        join_date                channel_id                  name_cc  \
# 0     2010-12-21  UCsTcErHg8oDvUnTzoqsYeNw            Unbox Therapy
# 1     2015-10-19  UCOhHO2ICt0ti9KAh-QHvttQ         Technical Guruji
# 2     2012-05-18  UCe_vXdMrHHseZ_esYUskSBw       CrazyRussianHacker
# 3     2005-06-22  UCE_M8A5yxnLfW0KghEeajjw                    Apple
# 4     2008-03-21  UCBJycsmduvYEL83R_U4JriQ         Marques Brownlee
# ...          ...                       ...                      ...
# 1188  2012-06-06  UCgMHqEDFll6X962CgXPzh4w           FocusCamera TV
# 1189  2018-02-25  UCJjacdkHH7Zxw8ouKQrirUg          The Best Coders
# 1190  2016-07-17  UCviAcL8AlEoGqLDWx7t_iPw               Mobile Tag
# 1191  2011-02-20  UCncAHfjOv1B_U8esTmLYukQ           Curtis Paradis
# 1192  2010-08-21  UCqcOdYkYBroLwnaKPWVdNRA  LavcoPriceIndustries...
#
#       subscribers_cc  videos_cc  subscriber_rank_sb  weights  \
# 0           15300000       1672               206.0   2.0870
# 1           13979890       2539               240.0   2.0870
# 2           11200000       1411               444.0   2.0870
# 3            9970000        291               489.0   2.0870
# 4            9400000       1148               530.0   2.0870
# ...              ...        ...                 ...      ...
# 1188           10000        278            940963.0  40.6530
# 1189           10200         28            941074.0  42.4845
# 1190           10300         20            952387.0  53.1435
# 1191           10300         97            963290.0  53.1435
# 1192           10100       1616            963759.0  53.1435
#
#       count_tech_videos  treat
# 0                 406.0      1
# 1                 209.0      1
# 2                 105.0      1
# 3                  64.0      1
# 4                 370.0      1
# ...                 ...    ...
# 1188               42.0      0
# 1189                2.0      0
# 1190                6.0      0
# 1191               11.0      1
# 1192              226.0      0
#
# [1193 rows x 9 columns]

# %% [markdown]
# ### Plots before the observational analysis

# %%
# we load the time series data.
path_time_series = "/Users/salma/Desktop/ADA/project/datasets/df_timeseries_en.tsv.gz"
time_series_data = pd.read_table(path_time_series)
display(time_series_data)
# Out:
#                            channel            category             datetime  \
# 0         UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-07-03 00:00:00
# 1         UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-07-10 00:00:00
# 2         UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-07-17 00:00:00
# 3         UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-07-24 00:00:00
# 4         UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-07-31 00:00:00
# ...                            ...                 ...                  ...
# 18872494  UC0UeVA9YHpOEr_Ng442xiRw              Gaming  2019-09-02 00:00:00
# 18872495  UC0UeVA9YHpOEr_Ng442xiRw              Gaming  2019-09-09 00:00:00
# 18872496  UC0UeVA9YHpOEr_Ng442xiRw              Gaming  2019-09-16 00:00:00
# 18872497  UC0UeVA9YHpOEr_Ng442xiRw              Gaming  2019-09-23 00:00:00
# 18872498  UC0UeVA9YHpOEr_Ng442xiRw              Gaming  2019-09-30 00:00:00
#
#                  views    delta_views          subs   delta_subs  videos  \
# 0         2.024946e+05       0.000000    650.222222     0.000000       5
# 1         3.940857e+05  191591.111111   1046.000000   395.777778       6
# 2         8.353938e+05  441308.083333   1501.500000   455.500000       6
# 3         1.104577e+06  269183.250000   1750.000000   248.500000       6
# 4         1.284406e+06  179828.600000   2008.300000   258.300000       6
# ...                ...            ...           ...          ...     ...
# 18872494  6.012938e+06  232418.277778  61268.611111  1305.611111     278
# 18872495  6.244579e+06  231640.888889  62631.666667  1363.055556     287
# 18872496  6.480902e+06  236322.933333  64010.000000  1378.333333     294
# 18872497  6.745317e+06  264415.200000  65480.000000  1470.000000     301
# 18872498  6.987738e+06  242420.771429  66542.857143  1062.857143     308
#
#           delta_videos  activity
# 0                    0         3
# 1                    1         1
# 2                    0         1
# 3                    0         0
# 4                    0         0
# ...                ...       ...
# 18872494             2        10
# 18872495             9        13
# 18872496             7        16
# 18872497             7        15
# 18872498             7        16
#
# [18872499 rows x 10 columns]

# %%
# filtering the time series data: keep the ones with a datetime from 15 days  before the release till 15 days after 
time_series_cop = time_series_data.copy()
time_series_cop["treat"] = 0
time_series_cop = time_series_cop.loc[(time_series_cop["datetime"] > '2017-10-15')& (time_series_cop["datetime"] <'2017-11-18')]

# %%
display(time_series_cop)
# Out:
#                            channel            category             datetime  \
# 15        UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-10-16 00:00:00
# 16        UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-10-23 00:00:00
# 17        UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-10-29 23:00:00
# 18        UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-11-05 23:00:00
# 19        UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-11-12 23:00:00
# ...                            ...                 ...                  ...
# 18872320  UC9fTi9wTYOtJZ6L8s07-bSQ              Comedy  2017-10-16 00:00:00
# 18872321  UC9fTi9wTYOtJZ6L8s07-bSQ              Comedy  2017-10-23 00:00:00
# 18872322  UC9fTi9wTYOtJZ6L8s07-bSQ              Comedy  2017-10-29 23:00:00
# 18872323  UC9fTi9wTYOtJZ6L8s07-bSQ              Comedy  2017-11-05 23:00:00
# 18872324  UC9fTi9wTYOtJZ6L8s07-bSQ              Comedy  2017-11-12 23:00:00
#
#                  views    delta_views          subs  delta_subs  videos  \
# 15        7.988571e+06  580410.250000  11618.250000  593.250000       7
# 16        8.573844e+06  585272.500000  12343.500000  725.250000       7
# 17        9.119252e+06  545408.104922  13053.787565  710.287565       8
# 18        9.654602e+06  535350.124244  13743.421875  689.634310       8
# 19        1.024755e+07  592948.239583  14536.526042  793.104167       9
# ...                ...            ...           ...         ...     ...
# 18872320  2.528257e+06   39748.250000   8853.222222  158.722222     316
# 18872321  2.568671e+06   40413.625000   9008.750000  155.527778     321
# 18872322  2.617294e+06   48623.426813   9186.927461  178.177461     327
# 18872323  2.687950e+06   70656.021103   9412.333333  225.405872     331
# 18872324  2.782732e+06   94781.750000   9692.333333  280.000000     340
#
#           delta_videos  activity  treat
# 15                   0         0      0
# 16                   0         0      0
# 17                   1         1      0
# 18                   0         1      0
# 19                   1         1      0
# ...                ...       ...    ...
# 18872320             1         6      0
# 18872321             5         7      0
# 18872322             6        11      0
# 18872323             4        13      0
# 18872324             9        13      0
#
# [553333 rows x 11 columns]

# %%
#With the list of treat channels, we transform the channel dataframe by adding the channel classification as treat/control
time_series_cop.loc[time_series_cop['channel'].isin(list_treat_channel),"treat"]= 1
display(time_series_cop)
# Out:
#                            channel            category             datetime  \
# 15        UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-10-16 00:00:00
# 16        UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-10-23 00:00:00
# 17        UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-10-29 23:00:00
# 18        UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-11-05 23:00:00
# 19        UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-11-12 23:00:00
# ...                            ...                 ...                  ...
# 18872320  UC9fTi9wTYOtJZ6L8s07-bSQ              Comedy  2017-10-16 00:00:00
# 18872321  UC9fTi9wTYOtJZ6L8s07-bSQ              Comedy  2017-10-23 00:00:00
# 18872322  UC9fTi9wTYOtJZ6L8s07-bSQ              Comedy  2017-10-29 23:00:00
# 18872323  UC9fTi9wTYOtJZ6L8s07-bSQ              Comedy  2017-11-05 23:00:00
# 18872324  UC9fTi9wTYOtJZ6L8s07-bSQ              Comedy  2017-11-12 23:00:00
#
#                  views    delta_views          subs  delta_subs  videos  \
# 15        7.988571e+06  580410.250000  11618.250000  593.250000       7
# 16        8.573844e+06  585272.500000  12343.500000  725.250000       7
# 17        9.119252e+06  545408.104922  13053.787565  710.287565       8
# 18        9.654602e+06  535350.124244  13743.421875  689.634310       8
# 19        1.024755e+07  592948.239583  14536.526042  793.104167       9
# ...                ...            ...           ...         ...     ...
# 18872320  2.528257e+06   39748.250000   8853.222222  158.722222     316
# 18872321  2.568671e+06   40413.625000   9008.750000  155.527778     321
# 18872322  2.617294e+06   48623.426813   9186.927461  178.177461     327
# 18872323  2.687950e+06   70656.021103   9412.333333  225.405872     331
# 18872324  2.782732e+06   94781.750000   9692.333333  280.000000     340
#
#           delta_videos  activity  treat
# 15                   0         0      0
# 16                   0         0      0
# 17                   1         1      0
# 18                   0         1      0
# 19                   1         1      0
# ...                ...       ...    ...
# 18872320             1         6      0
# 18872321             5         7      0
# 18872322             6        11      0
# 18872323             4        13      0
# 18872324             9        13      0
#
# [553333 rows x 11 columns]

# %%
#filtering the times series dataframe by channel's category
time_series_cop_2 = time_series_cop.copy()
time_series_cop_1 = time_series_cop.copy()
df_treat = time_series_cop_1.loc[time_series_cop_1["treat"] == 1]
df_control = time_series_cop_2.loc[time_series_cop_2["treat"] == 0]

# %%
display(df_treat)
display(df_control)
# Out:
#                            channel              category             datetime  \
# 28298     UC6tUZA7GiIZPaUu4FQXnFYA  Science & Technology  2017-10-16 00:00:00
# 28299     UC6tUZA7GiIZPaUu4FQXnFYA  Science & Technology  2017-10-23 00:00:00
# 28300     UC6tUZA7GiIZPaUu4FQXnFYA  Science & Technology  2017-10-29 23:00:00
# 28301     UC6tUZA7GiIZPaUu4FQXnFYA  Science & Technology  2017-11-05 23:00:00
# 28302     UC6tUZA7GiIZPaUu4FQXnFYA  Science & Technology  2017-11-12 23:00:00
# ...                            ...                   ...                  ...
# 18809359  UCTgyz9rBg2oVkSeeCOjPu8A  Science & Technology  2017-10-16 01:00:00
# 18809360  UCTgyz9rBg2oVkSeeCOjPu8A  Science & Technology  2017-10-23 01:00:00
# 18809361  UCTgyz9rBg2oVkSeeCOjPu8A  Science & Technology  2017-10-30 00:00:00
# 18809362  UCTgyz9rBg2oVkSeeCOjPu8A  Science & Technology  2017-11-06 00:00:00
# 18809363  UCTgyz9rBg2oVkSeeCOjPu8A  Science & Technology  2017-11-13 00:00:00
#
#                  views   delta_views          subs  delta_subs  videos  \
# 28298     4.481172e+06  68341.875000  17439.000000  307.125000     420
# 28299     4.540274e+06  59101.875000  17645.500000  206.500000     424
# 28300     4.602083e+06  61808.928109  17969.715026  324.215026     429
# 28301     4.665172e+06  63089.134391  18298.703125  328.988099     434
# 28302     4.736060e+06  70888.494792  18580.015625  281.312500     441
# ...                ...           ...           ...         ...     ...
# 18809359  6.046705e+05  37653.512500   1257.750000   77.920833     133
# 18809360  6.441633e+05  39492.817972   1335.216590   77.466590     133
# 18809361  6.835984e+05  39435.096774   1397.152074   61.935484     135
# 18809362  7.127160e+05  29117.585253   1464.500000   67.347926     143
# 18809363  7.579546e+05  45238.625000   1570.250000  105.750000     148
#
#           delta_videos  activity  treat
# 28298                5        14      1
# 28299                4         9      1
# 28300                5        10      1
# 28301                5        11      1
# 28302                7        12      1
# ...                ...       ...    ...
# 18809359             2         5      1
# 18809360             0         3      1
# 18809361             2         2      1
# 18809362             8        10      1
# 18809363             5        14      1
#
# [4154 rows x 11 columns]
#                            channel            category             datetime  \
# 15        UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-10-16 00:00:00
# 16        UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-10-23 00:00:00
# 17        UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-10-29 23:00:00
# 18        UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-11-05 23:00:00
# 19        UCBJuEqXfXTdcPSbGO9qqn1g  Film and Animation  2017-11-12 23:00:00
# ...                            ...                 ...                  ...
# 18872320  UC9fTi9wTYOtJZ6L8s07-bSQ              Comedy  2017-10-16 00:00:00
# 18872321  UC9fTi9wTYOtJZ6L8s07-bSQ              Comedy  2017-10-23 00:00:00
# 18872322  UC9fTi9wTYOtJZ6L8s07-bSQ              Comedy  2017-10-29 23:00:00
# 18872323  UC9fTi9wTYOtJZ6L8s07-bSQ              Comedy  2017-11-05 23:00:00
# 18872324  UC9fTi9wTYOtJZ6L8s07-bSQ              Comedy  2017-11-12 23:00:00
#
#                  views    delta_views          subs  delta_subs  videos  \
# 15        7.988571e+06  580410.250000  11618.250000  593.250000       7
# 16        8.573844e+06  585272.500000  12343.500000  725.250000       7
# 17        9.119252e+06  545408.104922  13053.787565  710.287565       8
# 18        9.654602e+06  535350.124244  13743.421875  689.634310       8
# 19        1.024755e+07  592948.239583  14536.526042  793.104167       9
# ...                ...            ...           ...         ...     ...
# 18872320  2.528257e+06   39748.250000   8853.222222  158.722222     316
# 18872321  2.568671e+06   40413.625000   9008.750000  155.527778     321
# 18872322  2.617294e+06   48623.426813   9186.927461  178.177461     327
# 18872323  2.687950e+06   70656.021103   9412.333333  225.405872     331
# 18872324  2.782732e+06   94781.750000   9692.333333  280.000000     340
#
#           delta_videos  activity  treat
# 15                   0         0      0
# 16                   0         0      0
# 17                   1         1      0
# 18                   0         1      0
# 19                   1         1      0
# ...                ...       ...    ...
# 18872320             1         6      0
# 18872321             5         7      0
# 18872322             6        11      0
# 18872323             4        13      0
# 18872324             9        13      0
#
# [549179 rows x 11 columns]

# %%
# We compare the number of subscribers and its evolution from 15 days before the release 
# till 15 days after this by plotting the evolution of the number of subscribers for the treat/control channels
plt.figure(figsize=(12,4))
sns.barplot(x = df_treat['datetime'], y = df_treat['delta_subs'])
plt.xticks(rotation=90)
plt.title('Evolution of number of subscribers for the treat channels before the  release and after')
plt.show()

plt.figure(figsize=(12,4))
sns.barplot(x = df_control['datetime'], y = df_control['delta_subs'])
plt.xticks(rotation=90)
plt.title('Evolution of number of subscribers for the control channels before the release and after')
plt.show()

# %% [markdown]
# ### Conclusion from the plots
# The release date is "2017-11-03". We can see that the treat channels (that talk about the release) have more subscribers than the control ones, which don't talk about it. This could even be observed before the release. It is as if the already successful review channels will be the ones that will talk about it. The rise in the subscriber number coincides with the release period (data of "2017-11-05") for the treat channels.This difference in subscribers' number between the treat and control channels appears also far after the release event. We can conclude that there is a kind of long-term effect of talking about the release on the success of the channel, represented by its number of subscribers. Hence, the channels that talk about the release of iPhone x are more successful and have long-term success with a higher number of subscribers.

# %% [markdown]
# ### To do for milestone 3: generalize to other events, do the observational study (causal analysis) (cf. lab5) and plots after the analysis
